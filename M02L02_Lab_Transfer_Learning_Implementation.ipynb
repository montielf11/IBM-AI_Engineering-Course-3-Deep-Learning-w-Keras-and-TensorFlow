# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Lab: Transfer Learning Implementation

# %% [markdown]
# ##### Estimated time needed:  30 minutes

# %% [markdown]
# In this lab, you will learn to implement transfer learning using a pre-trained model in Keras.
#
# #### Learning objectives
#
# By the end of this lab, you will:
#
#  - Import necessary libraries and load the dataset.
#  - Load a pre-trained model, VGG16, excluding the top layers.
#  - Add new layers on top of the base model and compile the model.
#  - Train the model on the new dataset.
#  - Unfreeze some of the layers of the pre-trained model and fine-tune them.

# %% [markdown]
# ### Step-by-Step Guide:
#
# #### Step 1: Setup the Environment
#
# Before we start, make sure to import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras`.

# %%
# !pip install tensorflow==2.16.2 matplotlib==3.9.1
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# Requirement already satisfied: tensorflow==2.16.2 in /opt/conda/lib/python3.12/site-packages (2.16.2)
# Requirement already satisfied: matplotlib==3.9.1 in /opt/conda/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.74.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (3.11.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.1) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.16.2) (0.45.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (14.1.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.1.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2) (0.1.2)

# %% [markdown]
# ##### Explanation:
# - `tensorflow` is the main library for machine learning in Python.
# - `Sequential` is used to create a model with a linear stack of layers.
# - `Dense` and `Flatten` are types of layers that we will use in our model.

# %% [markdown]
# #### Step 2: Load Pre-trained Model

# %%
# Load the VGG16 model pre-trained on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# #### Step 3: Create and Compile the Model

# %%
# Create a new model and add the base model and new layers
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')  # Change to the number of classes you have
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### **Create Placeholder Images**

# %%
import os
from PIL import Image
import numpy as np

# Create directories if they don't exist
os.makedirs('sample_data/class_a', exist_ok=True)
os.makedirs('sample_data/class_b', exist_ok=True)

# Create 10 sample images for each class
for i in range(10):
    # Create a blank white image for class_a
    img = Image.fromarray(np.ones((224, 224, 3), dtype=np.uint8) * 255)
    img.save(f'sample_data/class_a/img_{i}.jpg')

    # Create a blank black image for class_b
    img = Image.fromarray(np.zeros((224, 224, 3), dtype=np.uint8))
    img.save(f'sample_data/class_b/img_{i}.jpg')

print("Sample images created in 'sample_data/'")
# Out:
# Sample images created in 'sample_data/'

# %% [markdown]
# #### Step 4: Train the Model

# %%
# Load and preprocess the dataset
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Verify if the generator has loaded images correctly
print(f"Found {train_generator.samples} images belonging to {train_generator.num_classes} classes.")

# Train the model
if train_generator.samples > 0:
    model.fit(train_generator, epochs=10)
# Out:
# Found 20 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step - accuracy: 0.5000 - loss: 0.7884
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 6.6787
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 3.8108
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 1.0000 - loss: 0.3893
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 1.1482
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 1.2397
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 1.2303
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.5000 - loss: 1.1699
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 1.0789
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.5000 - loss: 0.9729

# %% [markdown]
# #### Step 5: Fine-Tune the Model

# %%
# Unfreeze the top layers of the base model 

for layer in base_model.layers[-4:]:
    layer.trainable = True 

# Compile the model again 
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) 

# Train the model again 
model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - accuracy: 0.5000 - loss: 0.8652
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step - accuracy: 0.5000 - loss: 5.8836
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 2.4306
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.7056
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.7101
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.6859
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.6561
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.6287
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.6143
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.5000 - loss: 0.6299

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Exercise 1: Visualize Training and Validation Loss
#
# **Objective:** Plot the training and validation loss to observe the learning process of the model.
#
# **Instructions:**
# 1. Modify the training code to include validation data.
# 2. Plot the training and validation loss for each epoch.

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training'
)


##validation data
validation_generator=train_datagen.flow_from_directory(
    'sample_data',
    target_size=(224,224),
    batch_size=32,
    class_mode='binary',
    subset='validation')

history=model.fit(train_generator, validation_data= validation_generator, epochs=10)

#Plot the loss
plt.figure(figsize=(8,5)) 
plt.plot(history.history['loss'], label='Training Loss') 
plt.plot(history.history['val_loss'], label='Validation Loss') 
plt.title('Model Loss Over Epochs') 
plt.xlabel('Epochs')
plt.ylabel('Loss') 
plt.legend() 
plt.grid(True) 
plt.show()
# Out:
# Found 16 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 1.0000 - loss: 0.4839 - val_accuracy: 1.0000 - val_loss: 0.4017
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.4017 - val_accuracy: 0.5000 - val_loss: 0.4031
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step - accuracy: 0.5000 - loss: 0.4031 - val_accuracy: 0.5000 - val_loss: 1.0657
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 0.5000 - loss: 1.0657 - val_accuracy: 1.0000 - val_loss: 0.3450
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 1.0000 - loss: 0.3450 - val_accuracy: 0.5000 - val_loss: 0.4487
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - accuracy: 0.5000 - loss: 0.4487 - val_accuracy: 1.0000 - val_loss: 0.1356
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.1356 - val_accuracy: 1.0000 - val_loss: 0.3276
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.3276 - val_accuracy: 1.0000 - val_loss: 0.0556
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.0556 - val_accuracy: 1.0000 - val_loss: 0.0772
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.0772 - val_accuracy: 1.0000 - val_loss: 0.1243

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# # Modify data generator to include validation data
# train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
#
# train_generator = train_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary',
#     subset='training'
# )
#
# validation_generator = train_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary',
#     subset='validation'
# )
#
# # Train the model with validation data
# history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation loss
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %% [markdown]
# #### Exercise 2: Experiment with Different Optimizers
#
# **Objective:** Experiment with different optimizers and observe their impact on model performance.
#
# **Instructions:**
# 1. Change the optimizer from `adam` to `sgd` and `rmsprop`.
# 2. Retrain the model with each optimizer and compare the accuracy.

# %%
from tensorflow.keras.models import clone_model
import matplotlib.pyplot as plt

# Function to reset the model weights
def reset_model(model):
    # Clone the model to reset weights
    model_clone = clone_model(model)
    model_clone.set_weights(model.get_weights())
    return model_clone

# Prepare to reset the model for each optimizer test
initial_model = reset_model(model)  # Assume 'model' is the initial compiled model

# Experiment with SGD optimizer
sgd_model = reset_model(initial_model)  # Reset model
sgd_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
history_sgd = sgd_model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Plot training and validation accuracy for SGD
plt.plot(history_sgd.history['accuracy'], label='Training Accuracy SGD')
plt.plot(history_sgd.history['val_accuracy'], label='Validation Accuracy SGD')
plt.title('Training and Validation Accuracy with SGD')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Experiment with RMSprop optimizer
rmsprop_model = reset_model(initial_model)  # Reset model
rmsprop_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
history_rmsprop = rmsprop_model.fit(train_generator, epochs=10, validation_data=validation_generator)

# Plot training and validation accuracy for RMSprop
plt.plot(history_rmsprop.history['accuracy'], label='Training Accuracy RMSprop')
plt.plot(history_rmsprop.history['val_accuracy'], label='Validation Accuracy RMSprop')
plt.title('Training and Validation Accuracy with RMSprop')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 1.0000 - loss: 0.1243 - val_accuracy: 0.5000 - val_loss: 0.3558
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.3558 - val_accuracy: 0.5000 - val_loss: 5.9866
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 5.9866 - val_accuracy: 0.5000 - val_loss: 0.5989
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - accuracy: 0.5000 - loss: 0.5989 - val_accuracy: 0.5000 - val_loss: 0.4669
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.4669 - val_accuracy: 1.0000 - val_loss: 0.3895
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.3895 - val_accuracy: 1.0000 - val_loss: 0.3350
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.3350 - val_accuracy: 1.0000 - val_loss: 0.2901
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.2901 - val_accuracy: 1.0000 - val_loss: 0.2460
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step - accuracy: 1.0000 - loss: 0.2460 - val_accuracy: 1.0000 - val_loss: 0.2126
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.2126 - val_accuracy: 1.0000 - val_loss: 0.1744
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 20s 20s/step - accuracy: 1.0000 - loss: 0.1243 - val_accuracy: 0.5000 - val_loss: 38.4314
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 38.4314 - val_accuracy: 0.5000 - val_loss: 1.2240
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 1.2240 - val_accuracy: 0.5000 - val_loss: 0.6951
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.6951 - val_accuracy: 0.5000 - val_loss: 0.5939
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.5939 - val_accuracy: 1.0000 - val_loss: 0.4536
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.4536 - val_accuracy: 0.5000 - val_loss: 0.4875
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.4875 - val_accuracy: 0.5000 - val_loss: 5.1679
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 5.1679 - val_accuracy: 0.5000 - val_loss: 0.8562
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 0.5000 - loss: 0.8562 - val_accuracy: 1.0000 - val_loss: 0.4659
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step - accuracy: 1.0000 - loss: 0.4659 - val_accuracy: 1.0000 - val_loss: 0.1850

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# from tensorflow.keras.models import clone_model
# import matplotlib.pyplot as plt
#
# # Function to reset the model weights
# def reset_model(model):
#     # Clone the model to reset weights
#     model_clone = clone_model(model)
#     model_clone.set_weights(model.get_weights())
#     return model_clone
#
# # Prepare to reset the model for each optimizer test
# initial_model = reset_model(model)  # Assume 'model' is the initial compiled model
#
# # Experiment with SGD optimizer
# sgd_model = reset_model(initial_model)  # Reset model
# sgd_model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
# history_sgd = sgd_model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation accuracy for SGD
# plt.plot(history_sgd.history['accuracy'], label='Training Accuracy SGD')
# plt.plot(history_sgd.history['val_accuracy'], label='Validation Accuracy SGD')
# plt.title('Training and Validation Accuracy with SGD')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()
#
# # Experiment with RMSprop optimizer
# rmsprop_model = reset_model(initial_model)  # Reset model
# rmsprop_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
# history_rmsprop = rmsprop_model.fit(train_generator, epochs=10, validation_data=validation_generator)
#
# # Plot training and validation accuracy for RMSprop
# plt.plot(history_rmsprop.history['accuracy'], label='Training Accuracy RMSprop')
# plt.plot(history_rmsprop.history['val_accuracy'], label='Validation Accuracy RMSprop')
# plt.title('Training and Validation Accuracy with RMSprop')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %% [markdown]
# #### Exercise 3: Evaluate the Model on a Test Set
#
# **Objective:** Evaluate the fine-tuned model on an unseen test set to assess its generalization performance.
#
# **Instructions:**
# 1. Load a separate test set.
# 2. Evaluate the model on this test set and report the accuracy and loss.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'sample_data',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

# Evaluate the fine-tuned model on the test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Found 20 images belonging to 2 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 1.0000 - loss: 0.1243
# Test Accuracy: 100.00%
# Test Loss: 0.1243

# %% [markdown]
# <details>
# <summary>Click here for solution</summary> </br>
#
# ```python
# # Load and preprocess the test dataset
# test_datagen = ImageDataGenerator(rescale=1./255)
# test_generator = test_datagen.flow_from_directory(
#     'sample_data',
#     target_size=(224, 224),
#     batch_size=32,
#     class_mode='binary'
# )
#
# # Evaluate the fine-tuned model on the test set
# test_loss, test_accuracy = model.evaluate(test_generator)
# print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# print(f'Test Loss: {test_loss:.4f}')

# %% [markdown]
# ### Summary
#
# By completing these exercises, students will:
#
# 1. Visualize the training and validation loss to gain insights into the training process.
# 2. Experiment with different optimizers to understand their impact on model performance.
# 3. Evaluate the fine-tuned model on an unseen test set to assess its generalization capability.

# %% [markdown]
# #### Conclusion
#
# Congratulations! In this lab, you have successfully implemented transfer learning using a pre-trained model in Keras. This lab exercise demonstrated how to train and fine-tune the model by unfreezing some of the layers.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
